# %%
from transformers import BertTokenizer, BertModel

import numpy as np
import pandas as pd
#from transformers import BertTokenizer, BertModel
import torch


from tqdm.notebook import tqdm


from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

from transformers import AdamW, get_linear_schedule_with_warmup

from sklearn.metrics import f1_score
import random
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from pycm import *

import math
import torch.nn as nn
from torch.nn import CrossEntropyLoss, MSELoss

import time
import torch.optim as optim
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
# transform the dataset
from imblearn.over_sampling import SMOTE
from sklearn.metrics import matthews_corrcoef

# %%
MAIN_DF = pd.read_csv("D:\\Mohammad Dehghan\\NAICS\\Data\\Matched CAN Results from _XZ\\Can Matched Large Bert Embeddings 221115\\ca_matched_bert_embed_df_221114.csv",
                                encoding='utf-8-sig')

# %%
################################################################################
# 
# Preprocessing function
# Cleanses the NAICS column, extraction the year and the month of 
# the date column and filtering out the applications that have been file before 2017.

# Args:
#   DF (dataframe): The main dataset with variables such as file number, firm size, file dating,
#                     and NAICS code

# Returns: 
#  MAIN_DF (dataframe): A dataframe in which the NAICS column has been cleaned and date column 
#                       has been splitted into two columns YEAR and MONTH.
################################################################################

def PREPROCESSING(DF):
    COL = input("Insert the name of the NAICS column to be cleaned: ")
    CLEANED_DF = DF[DF[COL] != "000000"]
    CLEANED_DF = CLEANED_DF[CLEANED_DF[COL] != "      "]
    CLEANED_DF=CLEANED_DF.dropna(subset=[COL])
    CLEANED_DF[COL] = CLEANED_DF[COL].astype(int)
    CLEANED_DF = CLEANED_DF[CLEANED_DF[COL] != 0]
    CLEANED_DF[COL] = CLEANED_DF[COL].astype(str)
    CLEANED_DF[COL]=CLEANED_DF[COL].str[:6]
    
    DATE = input("Insert the name of the date column: ")

    CLEANED_DF["YEAR"] = pd.DatetimeIndex(CLEANED_DF[DATE]).year
    CLEANED_DF["MONTH"] = pd.DatetimeIndex(CLEANED_DF[DATE]).month
    CLEANED_DF=CLEANED_DF[CLEANED_DF['YEAR']>2016]
    CLEANED_DF=CLEANED_DF.reset_index(drop=True)
    
    return CLEANED_DF

# %%
################################################################################
# 
# Aggregating function
# Sums the BERT embedding vectors came from the observations in each application.
# Here in our case, the large based BERT embedding has 1024 elements (X1,...,X1024).
# Args:
#   DF (dataframe): A cleaned dataset which is the output of the preprocessing function.
# Returns: 
#  DF_ (dataframe): An aggregated dataframe based on embedding vectors.
################################################################################

def AGGREGATE(DF):
    FILE_NUMBER = input("Insert the name of the unique file number column: ")
    col_x = []
    for i in range(1024):
        col_x.append("X" + str(i+1))

    DF_GROUP = DF.groupby(FILE_NUMBER)[col_x].sum().reset_index()
    
    DF_NOT_X = DF.drop(col_x, axis=1)


    DF_GROUP_MERGE = DF_NOT_X.merge(DF_GROUP,
                                on=[FILE_NUMBER],
                                            how='left')
    DF_ = DF_GROUP_MERGE.drop_duplicates([FILE_NUMBER], keep='last')
    
    return DF_

# %%
################################################################################
# 
# Extract function
# Extracts the applications associated with NAICS codes which have more than 10 applications.
# This is because the smote() function for oversampling the data does not work 
# for low-frequent NAICS classes. It also ranks the NAICS code in a descending way and
# label them as NAICS_RANK.

# Args:
#   DF (dataframe): An aggregated dataframe, per NAICS per application

# Returns: 
#  CLEANED_DF_UPD_JOIN (dataframe): A dataframe in which low-frequent NAICS codes are excluded
#  and some main variables have been put on first columns of the dataframe.

################################################################################


def EXTRACT(DF):
    COL = input("Insert the name of the NAICS column to be counted for ranking and filtering: ")
    NAICS_CODE_SUMMARY=DF.groupby(by=[COL]).count()

    NAICS_CODE_SUMMARY=DF.assign(
        NUM_FILINGS = 
        DF
        .groupby([COL])[COL].transform('count')
        
    )

    NAICS_CODE_SUMMARY=NAICS_CODE_SUMMARY[[COL,'NUM_FILINGS']]
    NAICS_CODE_SUMMARY=NAICS_CODE_SUMMARY.reset_index(drop=True)
    NAICS_CODE_SUMMARY=NAICS_CODE_SUMMARY.sort_values(by=['NUM_FILINGS'], ascending=False)
    NAICS_CODE_SUMMARY=NAICS_CODE_SUMMARY.drop_duplicates(subset=[COL])
    NAICS_CODE_SUMMARY=NAICS_CODE_SUMMARY[NAICS_CODE_SUMMARY['NUM_FILINGS']>10]
    NAICS_CODE_SUMMARY=NAICS_CODE_SUMMARY.reset_index(drop=True)
    NAICS_CODE_SUMMARY['NAICS_RANK']=NAICS_CODE_SUMMARY.index

    CLEANED_DF_UPD=DF.copy()
    CLEANED_DF_UPD=CLEANED_DF_UPD[CLEANED_DF_UPD[COL].isin(NAICS_CODE_SUMMARY[COL])]
    CLEANED_DF_UPD=CLEANED_DF_UPD.reset_index(drop=True)

    CLEANED_DF_UPD_JOIN=CLEANED_DF_UPD.merge(NAICS_CODE_SUMMARY,
                                on=[COL],
                                            how='left')
    # Rearranging some columns

    NAICS_RANK_TEMP = CLEANED_DF_UPD_JOIN['NAICS_RANK']
    CLEANED_DF_UPD_JOIN = CLEANED_DF_UPD_JOIN.drop(columns=['NAICS_RANK'])
    CLEANED_DF_UPD_JOIN.insert(loc=1, column='NAICS_RANK', value=NAICS_RANK_TEMP)

    NUM_FILINGS_TEMP = CLEANED_DF_UPD_JOIN['NUM_FILINGS']
    CLEANED_DF_UPD_JOIN = CLEANED_DF_UPD_JOIN.drop(columns=['NUM_FILINGS'])
    CLEANED_DF_UPD_JOIN.insert(loc=2, column='NUM_FILINGS', value=NUM_FILINGS_TEMP)

    YEAR_TEMP = CLEANED_DF_UPD_JOIN['YEAR']
    CLEANED_DF_UPD_JOIN = CLEANED_DF_UPD_JOIN.drop(columns=['YEAR'])
    CLEANED_DF_UPD_JOIN.insert(loc=3, column='YEAR', value=YEAR_TEMP)

    YEAR_TEMP = CLEANED_DF_UPD_JOIN['MONTH']
    CLEANED_DF_UPD_JOIN = CLEANED_DF_UPD_JOIN.drop(columns=['MONTH'])
    CLEANED_DF_UPD_JOIN.insert(loc=4, column='MONTH', value=YEAR_TEMP)
    
    return CLEANED_DF_UPD_JOIN

# %%
################################################################################
# 
# Making input variable function for Multi Layer Perceptron (MLP)
# Makes the input variable for MLP, based on the aggregated BERT embedding vector and some 
# categorical variables concatenated to the embedding vector.

# Args:
#   DF (dataframe): A dataframe with aggregated embedding vector and some 
# categorical variables such as te firm size, year, .... 

# Returns: 
#  X (A numpy array): A vector of the size of embedding vector plus some dummy variables
# concatenated to that. 
######################################################################################


def MLP_INPUT(DF):
    col_x = []
    for i in range(1024):
        col_x.append("X" + str(i+1))
        
    SEQUENCES_NP = DF[col_x].values.tolist()
    SEQUENCES_NP = np.array(SEQUENCES_NP)
    SEQUENCES_NP = SEQUENCES_NP.astype(np.float32)
    SEQUENCES_NP = torch.tensor(SEQUENCES_NP)

    sequences_np_stack_to_use = np.row_stack(SEQUENCES_NP)
    X_base_0 = sequences_np_stack_to_use.astype('float32')
    X_base=pd.DataFrame(X_base_0)
    X_base['index']=X_base.index
    
    DUMMY_LIST = []
    proc = True
    while proc:
        var = input("Enter a variable to be dummied, If not press 'no': ")
        if var == "no":
            proc = False
        else:
            DUMMY_LIST.append(var)
  
    X = X_base.copy()
    for var in DUMMY_LIST:
        VAR_DUMMY_DF = pd.get_dummies(DF[var])
        VAR_DUMMY_DF['index']=VAR_DUMMY_DF.index
        
        X = VAR_DUMMY_DF.merge(X,on=['index'],how='left')
        
    X = X.drop(columns=['index'])  
    X=X.to_numpy()
    X=X.astype('float32')

    return X

# %%
################################################################################
# 
# Making output variable function for Multi Layer Perceptron (MLP)
# Makes the output variable for MLP, based on the target variable (NAICS_RANK)in our dataframe. 

# Args:
#   DF (dataframe): A dataframe with a target variable (NAICS_RANK in our case).  

# Returns: 
#  Y5 (A numpy array): A vector of the size of the number of applications in our dataframe.
######################################################################################

def MLP_OUTPUT(DF):
    
    TARGET = input("Enter the name of target variable: ")
   
    Y5 = DF[TARGET].astype('int32')
    Y5 = np.array(list(Y5))
    
    return Y5

# %%
#################################################################

# Creates the structure of a Multi Layer Perceptron in which we have 2 hidden layers
# with relu functions on them as the activatuion function.
# The input layer size is our input vector that has already been created by MLP_INPUT function.
# The output layer size is our output vector that has already been created by MLP_OUTPUT function.
# The size the the first hidden layer will be identified later on and the size of the second 
# one is 128.
###################################################################

class Net(nn.Module):
    def __init__(self, input_size, hidden_size,  output5_size):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, 128) 
        #self.relu = nn.ReLU()
        
        self.fc7 = nn.Linear(128, output5_size)
        
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        
        out5 = self.fc7(out)
        return  out5

# %%
###################################################################

# Builds a model based on the NET class (MLP).

# Args:
#      X (A numpy array): The input vector of the MLP which is the BERT embedding vector 
#                         concatenated with some categorical variables.

#      Y5 (A numpy array): The output vector of the MLP which is the target variable (NAICS_RANK)
#                          for our classification task.
# return: 
#         model (an MLP): A deep neural network
#######################################################################

def BUILD_MODEL(X,Y5):
    #fitting parameters
    nb_features = 256
    Q = len(X[1])
    D5=len(np.unique(Y5))

    model = Net(Q, nb_features, D5)
    
    return model

# %%
#################################################################

# Evaluate the loss function in the last layer of MLP which is the cross entropy loss function.
# 
# Args: 
#   y_pred (A numpy array): The predicted target variable.
#   y_true (A numpy Array): The actual target variable.
#   log_vars (An scaler): An embedded scaler to the loss function to avoid overfitting

# Return:
#        loss (A number): The value of a loss function 
###################################################################

def criterion(y_pred, y_true, log_vars):
  
    precision = torch.exp(-log_vars)
        #diff = -logsoft_fun(y_pred[i]-y_true[i])
    
    loss_function = nn.CrossEntropyLoss()
    diff = loss_function(y_pred,  y_true.long())
        #diff = (y_pred[i]-y_true[i])**2.
        
    loss = precision * diff + log_vars
    
        
    return loss
#############################################################

# Shuffles the dataset
# Args:
#     X (a numpy array): A vector
#     Y5 (a numpy array): A vector
# Returns:
#     x[s] (a numpy array): A vector
#     Y5[s] (a numpy array): A vector

# Note that the vector X and Y5 should have the same length.
###############################################################

def shuffle_data(X,Y5):
    s = np.arange(X.shape[0])
    np.random.shuffle(s)
    return X[s],  Y5[s]




###################################################################

# Evaluates the loss function as well as the predicted target variablue.

# Args:
#      X (A numpy array): The input vector of the MLP which is the BERT embedding vector 
#                         concatenated with some categorical variables.

#      Y5 (A numpy array): The output vector of the MLP which is the target variable (NAICS_RANK)
#                          for our classification task.
# return: 
#         loss_val_avg (a number): The value of the loss function
#         predictions5 (a numpy array): the predicted target variable
#         true_vals5 (a numpy array): The true target variable
#######################################################################

def evaluate(X, Y5):

    model.eval()
    
    loss_val_total = 0
    predictions5,  true_vals5  =  [], []
    
    for j in range(len(X)//batch_size):
        
        
        
        inp = torch.from_numpy(X[(j*batch_size):((j+1)*batch_size)])
        
        target5 = torch.from_numpy(Y5[(j*batch_size):((j+1)*batch_size)])
        
        with torch.no_grad():        
            out = model(inp)
        
        
        
        loss = criterion(out, target5, log_var_e)
        
        loss_val_total += loss.item()
        
        
        predictions5.append(out.detach().numpy())
        
        true_vals5.append(target5.numpy())
        
    
    
    loss_val_avg = loss_val_total * batch_size /len(X)
    
    predictions5 = np.concatenate(predictions5, axis=0)
    
    
    true_vals5 = np.concatenate(true_vals5, axis=0)
    
            
    return loss_val_avg, predictions5,  true_vals5




##################################################################

# Evaluates the f1 score between two arrays.

# Args:
#      preds (A numpy array): the predicted target variable in which each element shows
#                           a vector that has as the same length as the number of classes
#                           and each element of the vector shows the probabilty of 
#                           an applicatio belonging to a class. 
#                           

#      labels (A numpy array): The true target variable which shows the groundtruth label
#                           (true class) of each application                     

# return: f1 score between two numpy arrays. 
#         
#######################################################################

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')







##################################################################

# Evaluates the Balance accuracy score between two arrays.

# Args:
#      preds (A numpy array): the predicted target variable in which each element shows
#                           a vector that has as the same length as the number of classes
#                           and each element of the vector shows the probabilty of 
#                           an applicatio belonging to a class. 
#                           

#      labels (A numpy array): The true target variable which shows the groundtruth label
#                           (true class) of each application                     

# return: Balance accuracy score between two numpy arrays. 
#         
#######################################################################

def BALANCED_ACCURACY(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return balanced_accuracy_score(labels_flat, preds_flat)

# %%
# Calculates the f1 score for each epoch for which the model is being trained.

# Args:
#   X_TRAIN (a numpy array): The training part of the input vector
#   Y5_TRAIN (a numpy array): The training part of the output vector
#   X_TEST (a numpy array): The testing part of the input vector
#   Y5_TEST (a numpy array): The testing part of the output vector
#   X_VAL (a numpy array): The validation part of the input vector
#   Y5_VAL (a numpy array): The validation part of the output vector

# Returns:
#         test_f1_5_list (a list of numbers): The calculated f1 score for each epoch

##############################################################################

def inner_cv_test(X_TRAIN,Y5_TRAIN,X_TEST,Y5_TEST,X_VAL,Y5_VAL):
    N = len(X_TRAIN)
    loss_history = np.zeros(nb_epoch)
    loss_history_val = np.zeros(nb_epoch)
    loss_history_test = np.zeros(nb_epoch)

    val_f1_5_list = np.zeros(nb_epoch)
    test_f1_5_list = np.zeros(nb_epoch)
    for i in range(nb_epoch):

        epoch_loss = 0
    
        X,  Y5 = shuffle_data(X_TRAIN, Y5_TRAIN)
        #X, Y1, Y2 = X_TRAIN, Y1_TRAIN, Y2_TRAIN
        for j in range(N//batch_size):

            optimizer.zero_grad()
            #print(X.shape[1])
            inp = torch.from_numpy(X[(j*batch_size):((j+1)*batch_size)])
            #print(inp.shape[1])
            target5 = torch.from_numpy(Y5[(j*batch_size):((j+1)*batch_size)])

            out = model(inp)

            loss = criterion(out, target5, log_var_e)

            epoch_loss += loss.item()

            loss.backward()

            optimizer.step()


        loss_history[i] = epoch_loss * batch_size / N 

        loss_val_avg, predictions5, true_vals5 = evaluate(X_VAL, Y5_VAL)
        #print("Validation loss: ", loss_val_avg)
        loss_history_val[i] = loss_val_avg


        val_f1_5 = f1_score_func(predictions5, true_vals5)
        val_f1_5_list[i] = val_f1_5



        ##############
        loss_test_avg, predictions5_test, true_test5 = evaluate(X_TEST, Y5_TEST)
        #print("Validation loss: ", loss_val_avg)
        loss_history_test[i] = loss_test_avg


        test_f1_5 = f1_score_func(predictions5_test, true_test5)
        #print(predictions5_test)
        test_f1_5_list[i] = test_f1_5
        #################

        print("Epoch: ", i+1)

        print("F1 Score (Weighted) for NAICS in validation set: ", val_f1_5)
        print("F1 Score (Weighted) for NAICS in test set: ", test_f1_5)
        
    
    return test_f1_5_list[i]






######################################################################

# Oversamples the dataset in order to have an imbalanced dataset using SMOTE() function and
# splitting the data into train, validation and test parts and then call the inner_cv_test()
# function to train the model

# Args:
#      X (A numpy array): The input vector of the MLP which is the BERT embedding vector 
#                         concatenated with some categorical variables.

#      Y5 (A numpy array): The output vector of the MLP which is the target variable (NAICS_RANK)
#                          for our classification task.
# Returns: 
#         return_vec (a list of number): The calculated f1 score for each epoch.

############################################################################


def iteration_cv_run(X,Y5):
    

    X_TRAIN_VAL, X_TEST, Y5_TRAIN_VAL, Y5_TEST = train_test_split(X, Y5,
        test_size=0.1, shuffle = True)

    # transform the dataset
    oversample = SMOTE()
    X_TRAIN_VAL, Y5_TRAIN_VAL = oversample.fit_resample(X_TRAIN_VAL, Y5_TRAIN_VAL)


    X_TRAIN, X_VAL, Y5_TRAIN, Y5_VAL = train_test_split(X_TRAIN_VAL, Y5_TRAIN_VAL, 
        test_size=0.2)
    


    return_vec=inner_cv_test(X_TRAIN,Y5_TRAIN,X_TEST,Y5_TEST,X_VAL,Y5_VAL)
    return return_vec

# %%
CLEANED_DF = PREPROCESSING(MAIN_DF)
DF_ = AGGREGATE(CLEANED_DF)
CLEANED_DF_UPD_JOIN = EXTRACT(DF_)
# Out:
# Insert the name of the NAICS column to be cleaned: NAICS_CODE
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Insert the name of the date column: FILING_DATE
# Insert the name of the unique file number column: UNIQUE_FILE_NUMBER
# Insert the name of the NAICS column to be counted for ranking and filtering: NAICS_CODE

# %%
X = MLP_INPUT(CLEANED_DF_UPD_JOIN)
Y5 = MLP_OUTPUT(CLEANED_DF_UPD_JOIN)
# Out:
# Enter a variable to be dummied, If not press 'no': EMPLOYMENT_CODE_12
# Enter a variable to be dummied, If not press 'no': YEAR
# Enter a variable to be dummied, If not press 'no': no
# Enter the name of target variable: NAICS_RANK

# %%
# fits the model on the dataset.
# Args:
#      X (A numpy array): The input vector of the MLP which is the BERT embedding vector 
#                         concatenated with some categorical variables.

#      Y5 (A numpy array): The output vector of the MLP which is the target variable (NAICS_RANK)
#                          for our classification task.
# Returns: 
#         model (a deep neural network): A fitted model based on our dataset.

############################################################################



def FIT_MODEL(X, Y5):
    
    global model
    model = BUILD_MODEL(X,Y5)
    
    global nb_epoch
    nb_epoch = 30
    global batch_size 
    batch_size = 64
    global log_var_e 
    log_var_e = torch.zeros((1,), requires_grad=True)
    global params 
    params = ([p for p in model.parameters()] +  [log_var_e] )
    global optimizer 
    optimizer = optim.SGD(params, lr=0.001, momentum=0.9)
    
    seq_len = 11
    desired_runs_seq=range(0,seq_len)
    for k in desired_runs_seq:
        print(k)
        if k == seq_len-1:
            nb_epoch = 1
        iteration_cv_run(X,Y5)
            
    return model

# %%
model_fitted = FIT_MODEL(X, Y5)
# Out:
# 0
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.007152676605913454
# F1 Score (Weighted) for NAICS in test set:  0.0027007095899665005
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.08091815725728542
# F1 Score (Weighted) for NAICS in test set:  0.01666598907177884
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.20851943028551662
# F1 Score (Weighted) for NAICS in test set:  0.04173665537181054
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.319711881476673
# F1 Score (Weighted) for NAICS in test set:  0.07933928715408299
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.4093881509225944
# F1 Score (Weighted) for NAICS in test set:  0.10273811193477371
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.48717857910190787
# F1 Score (Weighted) for NAICS in test set:  0.12494850681224513
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.5587378146566173
# F1 Score (Weighted) for NAICS in test set:  0.1501843738955179
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.5973420078977061
# F1 Score (Weighted) for NAICS in test set:  0.1548417020418236
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.6440911017865808
# F1 Score (Weighted) for NAICS in test set:  0.16546438564308752
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.6811071759521491
# F1 Score (Weighted) for NAICS in test set:  0.17603872037854462
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.7216076582409712
# F1 Score (Weighted) for NAICS in test set:  0.1937750268494629
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.7354670311998874
# F1 Score (Weighted) for NAICS in test set:  0.197994844986511
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.7455374485970123
# F1 Score (Weighted) for NAICS in test set:  0.20098107696899994
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.7644840503777693
# F1 Score (Weighted) for NAICS in test set:  0.20565149120198575
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.8006266988431249
# F1 Score (Weighted) for NAICS in test set:  0.23077804443092068
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.812429415499518
# F1 Score (Weighted) for NAICS in test set:  0.23229106279330383
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.8049639876402037
# F1 Score (Weighted) for NAICS in test set:  0.219637254117478
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.8217608032535512
# F1 Score (Weighted) for NAICS in test set:  0.23381625040044993
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.826098959433904
# F1 Score (Weighted) for NAICS in test set:  0.23438912168449955
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.8343180853958742
# F1 Score (Weighted) for NAICS in test set:  0.23966094315017272
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.8198149204541364
# F1 Score (Weighted) for NAICS in test set:  0.2388839512052177
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.8524813963605586
# F1 Score (Weighted) for NAICS in test set:  0.25613405524775285
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.852272690365256
# F1 Score (Weighted) for NAICS in test set:  0.2486256629325617
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.8426332265537461
# F1 Score (Weighted) for NAICS in test set:  0.23907558860788267
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.8477040191647646
# F1 Score (Weighted) for NAICS in test set:  0.2597505697238558
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.8645986705600324
# F1 Score (Weighted) for NAICS in test set:  0.2542389620417209
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.8723476998964025
# F1 Score (Weighted) for NAICS in test set:  0.2686443606412706
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.8727192905335862
# F1 Score (Weighted) for NAICS in test set:  0.256929411456533
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.8759771513681399
# F1 Score (Weighted) for NAICS in test set:  0.2613791018402493
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.8733387551365933
# F1 Score (Weighted) for NAICS in test set:  0.26477375904103717
# 1
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.8645173577762624
# F1 Score (Weighted) for NAICS in test set:  0.37521261276291507
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.8648653491224524
# F1 Score (Weighted) for NAICS in test set:  0.3489658609153374
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.8655774488420285
# F1 Score (Weighted) for NAICS in test set:  0.33018724254332266
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.8491905178203756
# F1 Score (Weighted) for NAICS in test set:  0.31106294401194434
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.8756280182472547
# F1 Score (Weighted) for NAICS in test set:  0.3168549062111545
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.884252917855264
# F1 Score (Weighted) for NAICS in test set:  0.3268269315263741
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.8919345620562976
# F1 Score (Weighted) for NAICS in test set:  0.33452990070102767
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.8921836637523682
# F1 Score (Weighted) for NAICS in test set:  0.32123796208015054
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.8884147632832423
# F1 Score (Weighted) for NAICS in test set:  0.3210343627548287
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9030055364385127
# F1 Score (Weighted) for NAICS in test set:  0.32695027968931717
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.8861889975688985
# F1 Score (Weighted) for NAICS in test set:  0.3118290576110801
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.8935499084138078
# F1 Score (Weighted) for NAICS in test set:  0.3106647915166272
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9005844005270894
# F1 Score (Weighted) for NAICS in test set:  0.32324012415782233
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.8992498290795163
# F1 Score (Weighted) for NAICS in test set:  0.31676279498388116
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.8816122859055311
# F1 Score (Weighted) for NAICS in test set:  0.31376945108655013
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9121334767235889
# F1 Score (Weighted) for NAICS in test set:  0.3173005341130885
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.909192154158431
# F1 Score (Weighted) for NAICS in test set:  0.3178859760701206
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9086403782280358
# F1 Score (Weighted) for NAICS in test set:  0.32302827386310984
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9074496001634356
# F1 Score (Weighted) for NAICS in test set:  0.32101247744873307
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.8920637240569336
# F1 Score (Weighted) for NAICS in test set:  0.30169630584967
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.8896792844438678
# F1 Score (Weighted) for NAICS in test set:  0.29921219383857733
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9097832373598672
# F1 Score (Weighted) for NAICS in test set:  0.3169577176437177
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9046978986527046
# F1 Score (Weighted) for NAICS in test set:  0.3118903062610668
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9005911437132685
# F1 Score (Weighted) for NAICS in test set:  0.31989774618089334
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.911063794632794
# F1 Score (Weighted) for NAICS in test set:  0.3080570767949889
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9020015940833024
# F1 Score (Weighted) for NAICS in test set:  0.3027701363791736
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9140134981163313
# F1 Score (Weighted) for NAICS in test set:  0.3152526339756675
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.8969941870469842
# F1 Score (Weighted) for NAICS in test set:  0.2989584342669291
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.9123595001464282
# F1 Score (Weighted) for NAICS in test set:  0.31948743428858967
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9171564821071955
# F1 Score (Weighted) for NAICS in test set:  0.3163187400416933
# 2
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9069677722372816
# F1 Score (Weighted) for NAICS in test set:  0.46812858538878427
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9137886774772201
# F1 Score (Weighted) for NAICS in test set:  0.4481046183081877
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.8965853131710932
# F1 Score (Weighted) for NAICS in test set:  0.4181988568738318
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.8928340650616954
# F1 Score (Weighted) for NAICS in test set:  0.4037642533944893
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9053282720389669
# F1 Score (Weighted) for NAICS in test set:  0.4022114808313423
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9133358108260703
# F1 Score (Weighted) for NAICS in test set:  0.4118563412383049
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9111182156796316
# F1 Score (Weighted) for NAICS in test set:  0.3953461846476858
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9171640741532865
# F1 Score (Weighted) for NAICS in test set:  0.40032073424416303
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9023088834474547
# F1 Score (Weighted) for NAICS in test set:  0.3738529847057549
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9236284142273985
# F1 Score (Weighted) for NAICS in test set:  0.3836775845212532
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9101481981137747
# F1 Score (Weighted) for NAICS in test set:  0.3700401411655998
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9233265866647108
# F1 Score (Weighted) for NAICS in test set:  0.39099271858189344
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.90064484169066
# F1 Score (Weighted) for NAICS in test set:  0.35267987779256355
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9182968288334932
# F1 Score (Weighted) for NAICS in test set:  0.36858047864699717
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9172346412594207
# F1 Score (Weighted) for NAICS in test set:  0.3625438929807493
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9147333741556417
# F1 Score (Weighted) for NAICS in test set:  0.37178825036524615
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9118346849529161
# F1 Score (Weighted) for NAICS in test set:  0.3598507980180325
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9192306781333024
# F1 Score (Weighted) for NAICS in test set:  0.34861085589543334
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.923414323957917
# F1 Score (Weighted) for NAICS in test set:  0.3579727526675546
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.928631705992534
# F1 Score (Weighted) for NAICS in test set:  0.3791789081292824
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9245895100409548
# F1 Score (Weighted) for NAICS in test set:  0.36279448368263734
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9212510175903986
# F1 Score (Weighted) for NAICS in test set:  0.36549777295426794
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9217860755996582
# F1 Score (Weighted) for NAICS in test set:  0.3533190846400866
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9087416119808195
# F1 Score (Weighted) for NAICS in test set:  0.35095418328696126
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9196129127558342
# F1 Score (Weighted) for NAICS in test set:  0.361176828178485
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.912699058471469
# F1 Score (Weighted) for NAICS in test set:  0.35322251234184193
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9274388994925602
# F1 Score (Weighted) for NAICS in test set:  0.35626050762460015
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9332825249390211
# F1 Score (Weighted) for NAICS in test set:  0.3570734575235319
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.9281700314238589
# F1 Score (Weighted) for NAICS in test set:  0.373230270916961
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9134555779510639
# F1 Score (Weighted) for NAICS in test set:  0.3492461336330528
# 3
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9157017878051075
# F1 Score (Weighted) for NAICS in test set:  0.5142719626159531
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9191919008835434
# F1 Score (Weighted) for NAICS in test set:  0.4885815829731096
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9137394358762831
# F1 Score (Weighted) for NAICS in test set:  0.4667776221045075
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.9184477323451143
# F1 Score (Weighted) for NAICS in test set:  0.457489127075472
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9294249627095423
# F1 Score (Weighted) for NAICS in test set:  0.4733198621697885
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9206528843125923
# F1 Score (Weighted) for NAICS in test set:  0.4485431243323416
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9277875275008867
# F1 Score (Weighted) for NAICS in test set:  0.46141236407673103
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9288222221178372
# F1 Score (Weighted) for NAICS in test set:  0.4340661249311219
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9305131792955565
# F1 Score (Weighted) for NAICS in test set:  0.4445030400896114
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9059982360806144
# F1 Score (Weighted) for NAICS in test set:  0.4100745188589355
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9119907498282058
# F1 Score (Weighted) for NAICS in test set:  0.3989732295287763
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9193054803667357
# F1 Score (Weighted) for NAICS in test set:  0.41478941671095043
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.925490890550053
# F1 Score (Weighted) for NAICS in test set:  0.41753354105621376
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9284182680694985
# F1 Score (Weighted) for NAICS in test set:  0.41772208609730993
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9282492412800433
# F1 Score (Weighted) for NAICS in test set:  0.4156588002948538
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9086362392386899
# F1 Score (Weighted) for NAICS in test set:  0.38420109598535235
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9303642458995581
# F1 Score (Weighted) for NAICS in test set:  0.4110014532592925
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9235424577374816
# F1 Score (Weighted) for NAICS in test set:  0.3878635704988529
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9339490139751033
# F1 Score (Weighted) for NAICS in test set:  0.4074418800047044
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9367936056866073
# F1 Score (Weighted) for NAICS in test set:  0.4127232028346299
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9341632434173025
# F1 Score (Weighted) for NAICS in test set:  0.40257266302868716
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9254987673045703
# F1 Score (Weighted) for NAICS in test set:  0.38196054997458473
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9162731745542196
# F1 Score (Weighted) for NAICS in test set:  0.38301820075025034
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9177845968180327
# F1 Score (Weighted) for NAICS in test set:  0.38598679871340796
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9164262916040373
# F1 Score (Weighted) for NAICS in test set:  0.36242776109632235
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9341326373927007
# F1 Score (Weighted) for NAICS in test set:  0.39666622249934397
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9317521721790181
# F1 Score (Weighted) for NAICS in test set:  0.38659960204587407
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9266970719779851
# F1 Score (Weighted) for NAICS in test set:  0.38680452339565824
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.933113787708623
# F1 Score (Weighted) for NAICS in test set:  0.37632505381796894
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9216134724389119
# F1 Score (Weighted) for NAICS in test set:  0.36749051770436236
# 4
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9341155415778113
# F1 Score (Weighted) for NAICS in test set:  0.5515716391314316
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9338656407208485
# F1 Score (Weighted) for NAICS in test set:  0.5286434758156192
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9354743335041057
# F1 Score (Weighted) for NAICS in test set:  0.5097522089141419
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.9134304513775923
# F1 Score (Weighted) for NAICS in test set:  0.4670310468809165
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9368946478154151
# F1 Score (Weighted) for NAICS in test set:  0.4993962046213562
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9222416121375819
# F1 Score (Weighted) for NAICS in test set:  0.4521847406310442
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9317531718021392
# F1 Score (Weighted) for NAICS in test set:  0.4629813507818467
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9312840305050749
# F1 Score (Weighted) for NAICS in test set:  0.4572692486104659
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9174277464576941
# F1 Score (Weighted) for NAICS in test set:  0.4478328908542337
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9308700352028482
# F1 Score (Weighted) for NAICS in test set:  0.44409890654221335
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9293270620187825
# F1 Score (Weighted) for NAICS in test set:  0.43338374381130923
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9393028460033822
# F1 Score (Weighted) for NAICS in test set:  0.4484419302891328
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9350850822092842
# F1 Score (Weighted) for NAICS in test set:  0.43043029185495707
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9376344962643537
# F1 Score (Weighted) for NAICS in test set:  0.44550466948286405
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9378670656773663
# F1 Score (Weighted) for NAICS in test set:  0.4383701639288585
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9363568648689155
# F1 Score (Weighted) for NAICS in test set:  0.4369098884808276
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9352780002172083
# F1 Score (Weighted) for NAICS in test set:  0.4339074884550157
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9326222921585606
# F1 Score (Weighted) for NAICS in test set:  0.4135149863669367
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9418668494811043
# F1 Score (Weighted) for NAICS in test set:  0.4347748345281553
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9267032959145487
# F1 Score (Weighted) for NAICS in test set:  0.3988642527300683
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9341838249503075
# F1 Score (Weighted) for NAICS in test set:  0.4145926516305638
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9358227978944761
# F1 Score (Weighted) for NAICS in test set:  0.4223657175674459
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9336548786026868
# F1 Score (Weighted) for NAICS in test set:  0.40700684635708395
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9322110491922831
# F1 Score (Weighted) for NAICS in test set:  0.4139285568680314
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9332244115171845
# F1 Score (Weighted) for NAICS in test set:  0.4097161991754477
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.931197016003119
# F1 Score (Weighted) for NAICS in test set:  0.41329923552122944
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9261755240520639
# F1 Score (Weighted) for NAICS in test set:  0.40583800514331086
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.919131894091505
# F1 Score (Weighted) for NAICS in test set:  0.39241842689012485
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.932199374207635
# F1 Score (Weighted) for NAICS in test set:  0.4026624375210543
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9424420552143122
# F1 Score (Weighted) for NAICS in test set:  0.40947288733437237
# 5
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9288711636098234
# F1 Score (Weighted) for NAICS in test set:  0.5549931444560854
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9070340371766658
# F1 Score (Weighted) for NAICS in test set:  0.4907039993315703
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9253993569761142
# F1 Score (Weighted) for NAICS in test set:  0.5094745581092297
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.9396102770343648
# F1 Score (Weighted) for NAICS in test set:  0.5126709471938645
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9360167312567855
# F1 Score (Weighted) for NAICS in test set:  0.5009500516964901
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9148590426746877
# F1 Score (Weighted) for NAICS in test set:  0.4756477192267349
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.931898460297374
# F1 Score (Weighted) for NAICS in test set:  0.48327535067513117
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9223542866135763
# F1 Score (Weighted) for NAICS in test set:  0.4663679980208894
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9326314626690856
# F1 Score (Weighted) for NAICS in test set:  0.4812912716406458
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9388550372191565
# F1 Score (Weighted) for NAICS in test set:  0.4852754119618151
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9374426643157493
# F1 Score (Weighted) for NAICS in test set:  0.47762434942830323
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9382396506372741
# F1 Score (Weighted) for NAICS in test set:  0.4782313550683883
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9338915344944352
# F1 Score (Weighted) for NAICS in test set:  0.46408067456388075
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9389041902700921
# F1 Score (Weighted) for NAICS in test set:  0.4676575805174982
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9373638713955154
# F1 Score (Weighted) for NAICS in test set:  0.4558390805275391
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9448992842629962
# F1 Score (Weighted) for NAICS in test set:  0.4681348989653701
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9376493744007157
# F1 Score (Weighted) for NAICS in test set:  0.4537199679553952
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9294050917619534
# F1 Score (Weighted) for NAICS in test set:  0.4335394729315973
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9337563596564837
# F1 Score (Weighted) for NAICS in test set:  0.43844958538690804
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9316800450092909
# F1 Score (Weighted) for NAICS in test set:  0.43538343602629426
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9402916039767084
# F1 Score (Weighted) for NAICS in test set:  0.4384704455636008
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9253051817956164
# F1 Score (Weighted) for NAICS in test set:  0.42925662568884887
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9251990368372517
# F1 Score (Weighted) for NAICS in test set:  0.41447113865399726
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9357765021059691
# F1 Score (Weighted) for NAICS in test set:  0.4197762527146775
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9353449349083293
# F1 Score (Weighted) for NAICS in test set:  0.4337039438417284
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9387246679072857
# F1 Score (Weighted) for NAICS in test set:  0.43204488980131006
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9418394899756602
# F1 Score (Weighted) for NAICS in test set:  0.4313327436734532
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9341380959837691
# F1 Score (Weighted) for NAICS in test set:  0.42177384364382575
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.930799439515769
# F1 Score (Weighted) for NAICS in test set:  0.41443256896368613
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9319073684188444
# F1 Score (Weighted) for NAICS in test set:  0.4173956712758713
# 6
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9324721644483607
# F1 Score (Weighted) for NAICS in test set:  0.5676969829938675
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9437311486838612
# F1 Score (Weighted) for NAICS in test set:  0.5708748796974489
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9433255703353779
# F1 Score (Weighted) for NAICS in test set:  0.5530069850137667
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.9400885147632712
# F1 Score (Weighted) for NAICS in test set:  0.529183109746111
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9379073545954848
# F1 Score (Weighted) for NAICS in test set:  0.530283835248902
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9441112822746353
# F1 Score (Weighted) for NAICS in test set:  0.5296154646522014
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9307232538026289
# F1 Score (Weighted) for NAICS in test set:  0.4848749421049877
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9461456172270456
# F1 Score (Weighted) for NAICS in test set:  0.5041658346002076
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9311257110539177
# F1 Score (Weighted) for NAICS in test set:  0.4742945852043962
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9462468358897732
# F1 Score (Weighted) for NAICS in test set:  0.4939935485054711
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9420497946644117
# F1 Score (Weighted) for NAICS in test set:  0.4868487956907609
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9322457043909045
# F1 Score (Weighted) for NAICS in test set:  0.4693610481489021
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9385894318303106
# F1 Score (Weighted) for NAICS in test set:  0.47541410581843146
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9441556447506247
# F1 Score (Weighted) for NAICS in test set:  0.4783260359256193
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9173554311775232
# F1 Score (Weighted) for NAICS in test set:  0.4400339949910577
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9355474400343735
# F1 Score (Weighted) for NAICS in test set:  0.45231025125763286
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9383764796113914
# F1 Score (Weighted) for NAICS in test set:  0.45995747509236884
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9364735749172028
# F1 Score (Weighted) for NAICS in test set:  0.45590019709408186
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9427805783612678
# F1 Score (Weighted) for NAICS in test set:  0.4643041864025332
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9176664583378557
# F1 Score (Weighted) for NAICS in test set:  0.4205300074782646
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9407579091217741
# F1 Score (Weighted) for NAICS in test set:  0.4481448602632166
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9498833915983498
# F1 Score (Weighted) for NAICS in test set:  0.46119037246103683
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9461610449077953
# F1 Score (Weighted) for NAICS in test set:  0.4587737919535249
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9341775364189828
# F1 Score (Weighted) for NAICS in test set:  0.44476903607672963
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9294401368627572
# F1 Score (Weighted) for NAICS in test set:  0.42996392648271525
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9381354085783374
# F1 Score (Weighted) for NAICS in test set:  0.4322120512219903
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9422978125553712
# F1 Score (Weighted) for NAICS in test set:  0.44196862442837664
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9415155324609206
# F1 Score (Weighted) for NAICS in test set:  0.4481985509752248
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.9434038648852142
# F1 Score (Weighted) for NAICS in test set:  0.4372370449980818
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.94027831853478
# F1 Score (Weighted) for NAICS in test set:  0.4327076940822985
# 7
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9403302642258003
# F1 Score (Weighted) for NAICS in test set:  0.5810594131627137
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.942967701681806
# F1 Score (Weighted) for NAICS in test set:  0.560624139962951
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9302046960694345
# F1 Score (Weighted) for NAICS in test set:  0.5285865397221182
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.9405503340786676
# F1 Score (Weighted) for NAICS in test set:  0.5426136741733801
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9399284425122802
# F1 Score (Weighted) for NAICS in test set:  0.524482146463138
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9460545892240693
# F1 Score (Weighted) for NAICS in test set:  0.5374147022820717
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9362767478626862
# F1 Score (Weighted) for NAICS in test set:  0.5050548199134476
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9505312134177385
# F1 Score (Weighted) for NAICS in test set:  0.5334108038009987
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.940495010698616
# F1 Score (Weighted) for NAICS in test set:  0.5207488155661062
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9440144897323476
# F1 Score (Weighted) for NAICS in test set:  0.5038227496568367
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9464058176757661
# F1 Score (Weighted) for NAICS in test set:  0.49892043775121303
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9143188726737871
# F1 Score (Weighted) for NAICS in test set:  0.45021597696246896
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9461068697850843
# F1 Score (Weighted) for NAICS in test set:  0.5059597422704419
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9428862233474401
# F1 Score (Weighted) for NAICS in test set:  0.4938928369511254
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9371800142039399
# F1 Score (Weighted) for NAICS in test set:  0.4919619622509779
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.944954423883272
# F1 Score (Weighted) for NAICS in test set:  0.49215731541749086
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9359334554436284
# F1 Score (Weighted) for NAICS in test set:  0.4653832944170701
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9470795158473797
# F1 Score (Weighted) for NAICS in test set:  0.4929740424653153
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9394289400648672
# F1 Score (Weighted) for NAICS in test set:  0.47441122078856546
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9433471811907292
# F1 Score (Weighted) for NAICS in test set:  0.4683617206565469
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9430758920542467
# F1 Score (Weighted) for NAICS in test set:  0.4810614798139572
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9386348252807426
# F1 Score (Weighted) for NAICS in test set:  0.45011649864332104
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9170432444501736
# F1 Score (Weighted) for NAICS in test set:  0.4363671958754768
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9353067499155446
# F1 Score (Weighted) for NAICS in test set:  0.45088446616739636
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9377890850885605
# F1 Score (Weighted) for NAICS in test set:  0.4556510747256539
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9393050929857064
# F1 Score (Weighted) for NAICS in test set:  0.4475508656820148
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9379256770261091
# F1 Score (Weighted) for NAICS in test set:  0.4365435640886884
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9370757087098327
# F1 Score (Weighted) for NAICS in test set:  0.443195739516284
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.9376323304055055
# F1 Score (Weighted) for NAICS in test set:  0.4484803990263534
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9411281070133453
# F1 Score (Weighted) for NAICS in test set:  0.45228468061133353
# 8
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9446604303501857
# F1 Score (Weighted) for NAICS in test set:  0.5949366552895639
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9477885197853947
# F1 Score (Weighted) for NAICS in test set:  0.5760516632728461
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9476535040851393
# F1 Score (Weighted) for NAICS in test set:  0.570336633462712
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.947863504611942
# F1 Score (Weighted) for NAICS in test set:  0.5634041102139665
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9481430893194615
# F1 Score (Weighted) for NAICS in test set:  0.5533214274771463
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.948090099862732
# F1 Score (Weighted) for NAICS in test set:  0.5478449010035984
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9504496830649983
# F1 Score (Weighted) for NAICS in test set:  0.5435037061624057
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9506183046660897
# F1 Score (Weighted) for NAICS in test set:  0.5304459701753331
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9481347723410084
# F1 Score (Weighted) for NAICS in test set:  0.5169240695027469
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9442846958644353
# F1 Score (Weighted) for NAICS in test set:  0.5087252160208331
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9473232826589698
# F1 Score (Weighted) for NAICS in test set:  0.5083248111175497
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9378714987829556
# F1 Score (Weighted) for NAICS in test set:  0.4892350072777997
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9329598445624742
# F1 Score (Weighted) for NAICS in test set:  0.48392034154313224
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.946807536367815
# F1 Score (Weighted) for NAICS in test set:  0.4926652191584132
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9474128539052142
# F1 Score (Weighted) for NAICS in test set:  0.48980731278043055
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9505570215695205
# F1 Score (Weighted) for NAICS in test set:  0.486736401697007
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9411061223445449
# F1 Score (Weighted) for NAICS in test set:  0.47208539370752756
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9362694465819226
# F1 Score (Weighted) for NAICS in test set:  0.467435950093989
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9461443796940019
# F1 Score (Weighted) for NAICS in test set:  0.47672798292851154
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9438889617285069
# F1 Score (Weighted) for NAICS in test set:  0.4612853502280673
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9280029218752031
# F1 Score (Weighted) for NAICS in test set:  0.44644796903830214
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9460152588247317
# F1 Score (Weighted) for NAICS in test set:  0.4675801709820669
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9372157142114184
# F1 Score (Weighted) for NAICS in test set:  0.4586600710519703
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9408750260412075
# F1 Score (Weighted) for NAICS in test set:  0.4515532814758808
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.9469985485673017
# F1 Score (Weighted) for NAICS in test set:  0.46129124961212725
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9471247669104574
# F1 Score (Weighted) for NAICS in test set:  0.455284589138597
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9524376057138754
# F1 Score (Weighted) for NAICS in test set:  0.4667070686456922
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9434104595759445
# F1 Score (Weighted) for NAICS in test set:  0.4503138126645754
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.9483117181411783
# F1 Score (Weighted) for NAICS in test set:  0.45953311322038826
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9439537478395696
# F1 Score (Weighted) for NAICS in test set:  0.4526088702345184
# 9
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9326064556769786
# F1 Score (Weighted) for NAICS in test set:  0.5771963341429363
# Epoch:  2
# F1 Score (Weighted) for NAICS in validation set:  0.9352006770784791
# F1 Score (Weighted) for NAICS in test set:  0.5837778912742312
# Epoch:  3
# F1 Score (Weighted) for NAICS in validation set:  0.9443537936771805
# F1 Score (Weighted) for NAICS in test set:  0.5827352368946542
# Epoch:  4
# F1 Score (Weighted) for NAICS in validation set:  0.9420807627481549
# F1 Score (Weighted) for NAICS in test set:  0.565639975685774
# Epoch:  5
# F1 Score (Weighted) for NAICS in validation set:  0.9457341916505732
# F1 Score (Weighted) for NAICS in test set:  0.5589406450585238
# Epoch:  6
# F1 Score (Weighted) for NAICS in validation set:  0.9433081256352311
# F1 Score (Weighted) for NAICS in test set:  0.5570902860495812
# Epoch:  7
# F1 Score (Weighted) for NAICS in validation set:  0.9473838401463888
# F1 Score (Weighted) for NAICS in test set:  0.5508644464030874
# Epoch:  8
# F1 Score (Weighted) for NAICS in validation set:  0.9506160505156274
# F1 Score (Weighted) for NAICS in test set:  0.5552733554351413
# Epoch:  9
# F1 Score (Weighted) for NAICS in validation set:  0.9420162119077835
# F1 Score (Weighted) for NAICS in test set:  0.5387814033509062
# Epoch:  10
# F1 Score (Weighted) for NAICS in validation set:  0.9458666436321946
# F1 Score (Weighted) for NAICS in test set:  0.5368979726909194
# Epoch:  11
# F1 Score (Weighted) for NAICS in validation set:  0.9318833488854732
# F1 Score (Weighted) for NAICS in test set:  0.5091056912531973
# Epoch:  12
# F1 Score (Weighted) for NAICS in validation set:  0.9441479854324234
# F1 Score (Weighted) for NAICS in test set:  0.5314644725152443
# Epoch:  13
# F1 Score (Weighted) for NAICS in validation set:  0.9495590273279855
# F1 Score (Weighted) for NAICS in test set:  0.5242832312415514
# Epoch:  14
# F1 Score (Weighted) for NAICS in validation set:  0.9362630468904896
# F1 Score (Weighted) for NAICS in test set:  0.5025596840510105
# Epoch:  15
# F1 Score (Weighted) for NAICS in validation set:  0.9310566840916079
# F1 Score (Weighted) for NAICS in test set:  0.49536567924346625
# Epoch:  16
# F1 Score (Weighted) for NAICS in validation set:  0.9361682686989062
# F1 Score (Weighted) for NAICS in test set:  0.5054197456666817
# Epoch:  17
# F1 Score (Weighted) for NAICS in validation set:  0.9532453298815246
# F1 Score (Weighted) for NAICS in test set:  0.5305979365240769
# Epoch:  18
# F1 Score (Weighted) for NAICS in validation set:  0.9474967536236677
# F1 Score (Weighted) for NAICS in test set:  0.5031843445936874
# Epoch:  19
# F1 Score (Weighted) for NAICS in validation set:  0.9475192379808016
# F1 Score (Weighted) for NAICS in test set:  0.5058848216206695
# Epoch:  20
# F1 Score (Weighted) for NAICS in validation set:  0.9468808170525826
# F1 Score (Weighted) for NAICS in test set:  0.5022734636164652
# Epoch:  21
# F1 Score (Weighted) for NAICS in validation set:  0.9467936925155629
# F1 Score (Weighted) for NAICS in test set:  0.49199680503413135
# Epoch:  22
# F1 Score (Weighted) for NAICS in validation set:  0.9466102569485664
# F1 Score (Weighted) for NAICS in test set:  0.4958504414227895
# Epoch:  23
# F1 Score (Weighted) for NAICS in validation set:  0.9296983104637712
# F1 Score (Weighted) for NAICS in test set:  0.4639772092514817
# Epoch:  24
# F1 Score (Weighted) for NAICS in validation set:  0.9465052102505102
# F1 Score (Weighted) for NAICS in test set:  0.4932287295740869
# Epoch:  25
# F1 Score (Weighted) for NAICS in validation set:  0.93915557981189
# F1 Score (Weighted) for NAICS in test set:  0.4773199776319398
# Epoch:  26
# F1 Score (Weighted) for NAICS in validation set:  0.9511108658849388
# F1 Score (Weighted) for NAICS in test set:  0.5031274144634468
# Epoch:  27
# F1 Score (Weighted) for NAICS in validation set:  0.9447263243575202
# F1 Score (Weighted) for NAICS in test set:  0.4842191919459426
# Epoch:  28
# F1 Score (Weighted) for NAICS in validation set:  0.9344424402866877
# F1 Score (Weighted) for NAICS in test set:  0.4598504740042714
# Epoch:  29
# F1 Score (Weighted) for NAICS in validation set:  0.8993715774699685
# F1 Score (Weighted) for NAICS in test set:  0.4285143596802025
# Epoch:  30
# F1 Score (Weighted) for NAICS in validation set:  0.9501277438117082
# F1 Score (Weighted) for NAICS in test set:  0.48804544162153135
# 10
# 1043
# 1043
# Epoch:  1
# F1 Score (Weighted) for NAICS in validation set:  0.9325331449480061
# F1 Score (Weighted) for NAICS in test set:  0.5891578654246061

# %%
# Shows the f1 score, Matthews Correction Coefficient (MCC) and balance accuracy
# of the pretrained model on a test dataset

# Args:
#     model (a classifier model): A model which has been trained already to classify
#                               the NAICS code for the application
 #    X (A numpy array): The input vector of the MLP which is the BERT embedding vector 
#                         concatenated with some categorical variables.

#     Y5 (A numpy array): The output vector of the MLP which is the target variable (NAICS_RANK)
#                          for our classification task.

###################################################################

def TEST_MODEL(model,X, Y5):
    X_TRAIN_VAL, X_TEST, Y5_TRAIN_VAL, Y5_TEST = train_test_split(X, Y5,
        test_size=0.1, shuffle = True)

    X_VAR=X_TEST
    Y_VAR=Y5_TEST
    model.eval()

    loss_val_total = 0
    predictions5,  true_vals5  =  [], []
    last_results_prediction=[]   
    last_results_target5=[]

    obs_index=[]


    for j in range(len(X_VAR)//batch_size):
        inp = torch.from_numpy(X_VAR[(j*batch_size):((j+1)*batch_size)])
        #print(inp.shape)
        target5 = torch.from_numpy(Y_VAR[(j*batch_size):((j+1)*batch_size)])

        with torch.no_grad():        
                out = model(inp)

        #print(out.detach().numpy().shape)
        loss = criterion(out, target5, log_var_e)
        #print(loss)
        loss_val_total += loss.item()


        predictions5.append(out.detach().numpy())

        last_results_prediction=out.detach().numpy()
        last_results_target5=target5.numpy()
        true_vals5.append(target5.numpy())
        temp_obs_index=range(j*batch_size,(j+1)*batch_size)
        obs_index.append(temp_obs_index)


    loss_val_avg = loss_val_total * batch_size /len(X_VAR)
    predictions5 = np.concatenate(predictions5, axis=0)
    true_vals5 = np.concatenate(true_vals5, axis=0)

    print("F1_score is: ",f1_score_func(predictions5, true_vals5))
    print("Matthews Correction Coefficient (MCC) is: ", matthews_corrcoef(np.argmax(predictions5, axis=1).flatten(), true_vals5))
    print("Balanced Accuracy is: ",BALANCED_ACCURACY(predictions5, true_vals5))

# %%
TEST_MODEL(model_fitted,X, Y5)
# Out:
# F1_score is:  0.6439046715848052
# Matthews Correction Coefficient (MCC) is:  0.6666092483500562
# Balanced Accuracy is:  0.8933052004594522
# C:\Users\mohammad.dehghan\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:2006: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
